# %%
import tensorflow as tf
from tensorflow import keras
import sklearn
import numpy as np
import pandas as pd
import os
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
path = "./datasets/iot-network-intrusion-dataset_190919/Packets_integrated/"
print(os.listdir(path))
# Out:
# ['benign-dec.pcap', 'dos-synflooding-1-6.pcap', 'dos-synflooding.csv', 'dos-synflooding_attacked.csv', 'mirai-ackflooding-1-4.pcap', 'mirai-ackflooding.csv', 'mirai-ackflooding_attacked.csv', 'mirai-hostbruteforce-1,3,5.pcap', 'mirai-hostbruteforce-1-5.pcap', 'mirai-hostbruteforce-2,4.pcap', 'mirai-hostbruteforce_1.csv', 'mirai-hostbruteforce_1_attacked.csv', 'mirai-hostbruteforce_2.csv', 'mirai-hostbruteforce_2_attacked.csv', 'mirai-httpflooding-1-4.pcap', 'mirai-httpflooding.csv', 'mirai-httpflooding_attacked.csv', 'mirai-udpflooding-1-4.pcap', 'mirai-udpflooding.csv', 'mirai-udpflooding_attacked.csv', 'mitm-arpspoofing-1-6.pcap', 'mitm.csv', 'MITM.txt', 'mitm_attacked.csv', 'scan-hostport-1-6.pcap', 'scan-hostport_1.csv', 'scan-hostport_1_attacked.csv', 'scan-hostport_2.csv', 'scan-hostport_2_attacked.csv', 'scan-hostport_3.csv', 'scan-hostport_3_attacked.csv', 'scan-hostport_4.csv', 'scan-hostport_4_attacked.csv', 'scan-hostport_5.csv', 'scan-hostport_5_attacked.csv', 'scan-hostp
# ...

# %%
csv_files = [f for f in os.listdir(path) if f.endswith('.csv')]

# %%
csv_files
# Out:
# ['dos-synflooding.csv',
#  'dos-synflooding_attacked.csv',
#  'mirai-ackflooding.csv',
#  'mirai-ackflooding_attacked.csv',
#  'mirai-hostbruteforce_1.csv',
#  'mirai-hostbruteforce_1_attacked.csv',
#  'mirai-hostbruteforce_2.csv',
#  'mirai-hostbruteforce_2_attacked.csv',
#  'mirai-httpflooding.csv',
#  'mirai-httpflooding_attacked.csv',
#  'mirai-udpflooding.csv',
#  'mirai-udpflooding_attacked.csv',
#  'mitm.csv',
#  'mitm_attacked.csv',
#  'scan-hostport_1.csv',
#  'scan-hostport_1_attacked.csv',
#  'scan-hostport_2.csv',
#  'scan-hostport_2_attacked.csv',
#  'scan-hostport_3.csv',
#  'scan-hostport_3_attacked.csv',
#  'scan-hostport_4.csv',
#  'scan-hostport_4_attacked.csv',
#  'scan-hostport_5.csv',
#  'scan-hostport_5_attacked.csv',
#  'scan-hostport_6.csv',
#  'scan-hostport_6_attacked.csv',
#  'scan-portos.csv',
#  'scan-portos_attacked.csv']

# %%
for i in range(len(csv_files)):
    print("attacked" in csv_files[i])
# Out:
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True

# %%
all_files=[]
all_labels=[]
for csv in csv_files:
    if "attacked" in csv:
        label = pd.read_csv(os.path.join(path, csv))
        all_labels.append(label["No."])
    else:
        file = pd.read_csv(os.path.join(path, csv), header=None)
        all_files.append(file)
# Out:
# C:\Users\hjhhi\anaconda3\envs\python3.6.8\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (0,1,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(len(all_files), len(all_labels))
# Out:
# 14 14

# %%
for i in range(1, len(all_files)-1):
    all_files[0].append(all_files[i])

# %%
all_files[0]
# Out:
#              0         1               2             3         4       5  \
# 0          No.      Time          Source   Destination  Protocol  Length
# 1            1  0.000000    192.168.0.13   192.168.0.1      ICMP     146
# 2            2  0.000545     192.168.0.1  192.168.0.13      ICMP     146
# 3            3  0.008112    192.168.0.13  192.168.0.23       TCP     843
# 4            4  0.008999    192.168.0.13  192.168.0.23       TCP     839
# ...        ...       ...             ...           ...       ...     ...
# 141705  141705    783705    192.168.0.23   224.0.0.251      MDNS     163
# 141706  141706    783705    192.168.0.23   224.0.0.251      MDNS     167
# 141707  141707    783705    192.168.0.23   224.0.0.251      MDNS     167
# 141708  141708    783705    192.168.0.23   224.0.0.251      MDNS     167
# 141709  141709    783707  74.125.203.189  192.168.0.14       UDP     129
#
#                                                         6
# ...

# %%
all_labels.append(pd.read_csv(os.path.join(path, csv_files[1])))

# %%
a = np.reshape(all_files,(-1, 7))
# Out:
# C:\Users\hjhhi\anaconda3\envs\python3.6.8\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
a.shape
# Out:
# (2, 7)

# %%
a = np.array(all_files)
# Out:
# C:\Users\hjhhi\anaconda3\envs\python3.6.8\lib\site-packages\ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.

# %%
b = np.reshape(a, (-1,7))

# %%
a.shape
# Out:
# (14,)

# %%
a.reshape(-1, 7)
# Out:
# (2, 7, 1)

# %%
a
# Out:
# array([             0         1               2             3         4       5  \
# 0          No.      Time          Source   Destination  Protocol  Length
# 1            1  0.000000    192.168.0.13   192.168.0.1      ICMP     146
# 2            2  0.000545     192.168.0.1  192.168.0.13      ICMP     146
# 3            3  0.008112    192.168.0.13  192.168.0.23       TCP     843
# 4            4  0.008999    192.168.0.13  192.168.0.23       TCP     839
# ...        ...       ...             ...           ...       ...     ...
# 141705  141705    783705    192.168.0.23   224.0.0.251      MDNS     163
# 141706  141706    783705    192.168.0.23   224.0.0.251      MDNS     167
# 141707  141707    783705    192.168.0.23   224.0.0.251      MDNS     167
# 141708  141708    783705    192.168.0.23   224.0.0.251      MDNS     167
# 141709  141709    783707  74.125.203.189  192.168.0.14       UDP     129
#
#                                                         6
# ...

# %%
a.shape
# Out:
#   File "<ipython-input-145-bc8d7e1a52a5>", line 4
# SyntaxError: can't use starred expression here
